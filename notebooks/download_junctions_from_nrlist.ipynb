# %% [markdown]
# # Extract junction loops from [RNA representative structures](http://rna.bgsu.edu/rna3dhub/nrlist)
# Since junction loop motifs are not available by [RNA 3D motif Atlas](http://rna.bgsu.edu/rna3dhub/motifs), download non-redundant RNA representative structures and extract junction loops manually

# %%
import os, sys, shutil
import pathlib
import glob as glob
import numpy as np
import json
import wget
import time
import warnings

# %%
def make_dir(output_path):
    """
    create directory
    """
    
    if os.path.isdir(output_path):
        print(">remove directory: {}".format(output_path))
        shutil.rmtree(output_path)
        
    pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
def download_csv(output_path, file, url_loop):
    """
    Download csv containing loop motif information
    
    Parameters
    ----------
    output_path : str
        File path pointing to the output directory 
    file : str
        CSV file in full path that contains non-redundant representative RNA information
    url_loop : str
        URL to download RNA loop strucutres (e.g. hairpin, internal, and junction) using BGSU API (https://www.bgsu.edu/research/rna/APIs.html)
    
    Returns
    -------
    """
    
    with open(file, "r") as f:
        for l in f.readlines():
            pdb  = l.split(',')[1].split('|')[0].replace('"', '')            
            csv  = os.path.join(output_path, "dump", pdb + "_loop.csv")                        
            _url = os.path.join(url_loop, pdb)
            
            try:
                # same pdb could be present with different chain id
                if os.path.isfile(csv):
                    #print("{} already found".format(os.path.basename(csv)))
                    pass
                else:
                    wget.download(_url, out=csv, bar=None)
            except:
                warnings.warn("Could not download {}\n{}".format(pdb, _url))
            
            time.sleep(1)  # avoid api traffic

# %%
def loadfile(file):
    """
    Load CSV file and get juction loop IDs
    
    Parameters
    ----------
    file : str
        CSV file in full path that stores loop IDs (e.g. hairpin: HP, internal: IL, junction: J3)
        
    Returns
    -------
    loop_ids : list of str
        List of junction loop IDs
    """
    
    loop_ids = []
    with open(file, 'r') as f:
        for l in f.readlines():
            
            # only extract junction loops
            if l.startswith('"J3_'):
                loop_id = l.split(',')[0].strip('"')
                loop_ids.append(loop_id)
            
        if len(loop_ids) == 0:
            print("no junction loops found: {}".format(os.path.basename(file)))
                
    return loop_ids

# %%
def download_cif(output_path, release_version, loop_ids, url_coord):
    """
    Download RNA coordinates using BGSU APIs (https://www.bgsu.edu/research/rna/APIs.html)
    
    Parameters
    ----------
    output_path : str
        Full path pointing to the output cif file
    release_version : str
        Release version of Representative sets of RNA 3D structures (http://rna.bgsu.edu/rna3dhub/nrlist)
    loop_ids : list of str
        Junciton loop id (e.g. J3_6SVS_002)
    url : str
        API url to download RNA coordinates
        
    Returns
    -------
    """
    
    for loop_id in loop_ids:
        _url = url_coord + loop_id
        cif = os.path.join(output_path, "dump", loop_id + ".cif")
        
        # check duplicate motif entry
        if os.path.exists(cif):
            warnings.warn("{} already exists. Duplicate motif entry.".format(loop_id))
        
        try:
            wget.download(_url, out=cif, bar=None)
            extract_model(output_path, release_version, cif) 
        except:
            warnings.warn("Could not download {}\n{}".format(loop_id, _url))

# %%
def extract_model(output_path, release_version, cif):
    """
    Extract the first model from the cif file. The downloaded cif file contains two models. Model 1 is the RNA motif of interset and model 2 is the neighboring structures of model 1. 
    
    Parameters
    ----------
    output_path : str
        Full path pointing to the output cif file
    release_version : str
        Release version of Representative sets of RNA 3D structures (http://rna.bgsu.edu/rna3dhub/nrlist)
    cif : str
        Downloaded cif file in full path
    
    Returns
    -------
    """
    arr = []
    count = 0
    with open(cif, "r") as f:
        for l in f.readlines():
            _l = l.strip('\n').split()[0]

            if _l.startswith("#"):
                count += 1
            if count == 2:    
                break
                
            arr.append(l)
    
    ofile = os.path.join(output_path, os.path.basename(cif))
    with open(ofile, "w") as wf:
        for l in arr:
            wf.write(l)

# %%
if __name__ == "__main__":
    
    url_coord = "http://rna.bgsu.edu/rna3dhub/rest/getCoordinates?coord="
    url_loop = "http://rna.bgsu.edu/rna3dhub/loops/download"
    base_path = os.path.dirname(os.path.abspath("__file__")).strip('notebooks')
    release_version = "nrlist_3.233_2.5A"    
    
    # create output directory
    output_path = os.path.join(base_path, "data", release_version, "JunctionLoop")
    make_dir(output_path)
    make_dir(os.path.join(output_path, "dump"))
    
    # download junction loops via RNA representative structures
    print(">download csv")
    file = os.path.join(base_path, "data", release_version + ".csv")
    download_csv(output_path, file, url_loop)    

    # extract loop junctions for each entry
    print(">download cif")
    files = glob.glob(os.path.join(output_path, "dump", "*_loop.csv"))
    for file in files:
        loop_ids = loadfile(file)
        download_cif(output_path, release_version, loop_ids, url_coord)
# Out:
# >download csv
# >download cif
# no junction loops found: 7OX9_loop.csv
# no junction loops found: 4XNR_loop.csv
# no junction loops found: 5HR7_loop.csv
# no junction loops found: 5NDH_loop.csv
# no junction loops found: 1ET4_loop.csv
# no junction loops found: 4NGD_loop.csv
# no junction loops found: 7BPV_loop.csv
# no junction loops found: 7D7W_loop.csv
# no junction loops found: 5EEU_loop.csv
# no junction loops found: 6O5F_loop.csv
# no junction loops found: 4QVD_loop.csv
# no junction loops found: 3K64_loop.csv
# no junction loops found: 6OZR_loop.csv
# no junction loops found: 1UVL_loop.csv
# no junction loops found: 1UVM_loop.csv
# no junction loops found: 1IHA_loop.csv
# no junction loops found: 7S3C_loop.csv
# no junction loops found: 7ECN_loop.csv
# no junction loops found: 5EV4_loop.csv
# no junction loops found: 7S3B_loop.csv
# no junction loops found: 7ECO_loop.csv
# no junction loops found: 6F4H_loop.csv
# no junction loops found: 3EQT_loop.csv
# no junction loops found: 3HSB_loop.csv
# no junction loops found: 3MJ0_loop.csv
# no junction loops found: 4OHZ_loop.csv
# no junction loops found: 6PPV_loop.csv
# no junction loops found: 5EME_loop.csv
# no junction loops found: 2ET8_loop.csv
# no junction loops found: 5UED_loop.csv
# no junction loops found: 7OZQ_loop.csv
# no junction loops found: 4P3T_loop.csv
# no junction loops found: 3R2D_loop.csv
# no junction loops found: 3P4C_loop.csv
# no junction loops found: 3X1L_loop.csv
# no junction loops found: 3D0M_loop.csv
# no junction loops found: 5BZU_loop.csv
# no junction loops found: 7MJY_loop.csv
# no junction loops found: 7P0V_loop.csv
# no junction loops found: 4I67_loop.csv
# no junction loops found: 3BT7_loop.csv
# no junction loops found: 2QUX_loop.csv
# no junction loops found: 7NJC_loop.csv
# no junction loops found: 7R9G_loop.csv
# no junction loops found: 5EIM_loop.csv
# no junction loops found: 2A0P_loop.csv
# no junction loops found: 4NIA_loop.csv
# no junction loops found: 3B5S_loop.csv
# no junction loops found: 3TZR_loop.csv
# no junction loops found: 4II9_loop.csv
# no junction loops found: 3BNT_loop.csv
# no junction loops found: 1G2E_loop.csv
# no junction loops found: 4D25_loop.csv
# no junction loops found: 1RPU_loop.csv
# no junction loops found: 5HBY_loop.csv
# no junction loops found: 5XTM_loop.csv
# no junction loops found: 6XUS_loop.csv
# no junction loops found: 6DU4_loop.csv
# no junction loops found: 1RNA_loop.csv
# no junction loops found: 2EZ6_loop.csv
# no junction loops found: 1ZH5_loop.csv
# no junction loops found: 5ZQ0_loop.csv
# no junction loops found: 2VAL_loop.csv
# no junction loops found: 5YKI_loop.csv
# no junction loops found: 6SVS_loop.csv
# no junction loops found: 6FZ0_loop.csv
# no junction loops found: 6HU6_loop.csv
# no junction loops found: 7S3H_loop.csv
# no junction loops found: 5C0Y_loop.csv
# no junction loops found: 433D_loop.csv
# no junction loops found: 3NMR_loop.csv
# no junction loops found: 6BGB_loop.csv
# no junction loops found: 1JZV_loop.csv
# no junction loops found: 5M0I_loop.csv
# no junction loops found: 1DUQ_loop.csv
# no junction loops found: 5Y6Z_loop.csv
# no junction loops found: 1WMQ_loop.csv
# no junction loops found: 1KD5_loop.csv
# no junction loops found: 5HNJ_loop.csv
# no junction loops found: 3KNC_loop.csv
# no junction loops found: 1KD4_loop.csv
# no junction loops found: 5UZ6_loop.csv
# no junction loops found: 1N35_loop.csv
# no junction loops found: 406D_loop.csv
# no junction loops found: 7THB_loop.csv
# no junction loops found: 4U35_loop.csv
# no junction loops found: 5T3K_loop.csv
# no junction loops found: 4U34_loop.csv
# no junction loops found: 7KFN_loop.csv
# no junction loops found: 4P5J_loop.csv
# no junction loops found: 2QUS_loop.csv
# no junction loops found: 6VRD_loop.csv
# no junction loops found: 7CGH_loop.csv
# no junction loops found: 4ENC_loop.csv
# no junction loops found: 1NUV_loop.csv
# no junction loops found: 2P7E_loop.csv
# no junction loops found: 3FOZ_loop.csv
# no junction loops found: 5LR4_loop.csv
# no junction loops found: 7MLX_loop.csv
# no junction loops found: 5LR5_loop.csv
# no junction loops found: 5VGW_loop.csv
# no junction loops found: 4P43_loop.csv
# no junction loops found: 5LQO_loop.csv
# no junction loops found: 4RCJ_loop.csv
# no junction loops found: 7N06_loop.csv
# no junction loops found: 3NNC_loop.csv
# no junction loops found: 6KUG_loop.csv
# no junction loops found: 419D_loop.csv
# no junction loops found: 5V3F_loop.csv
# no junction loops found: 5WWE_loop.csv
# no junction loops found: 7C45_loop.csv
# no junction loops found: 3C3Z_loop.csv
# no junction loops found: 6SZU_loop.csv
# no junction loops found: 4F3T_loop.csv
# no junction loops found: 7AAP_loop.csv
# no junction loops found: 1J6S_loop.csv
# no junction loops found: 3KS8_loop.csv
# no junction loops found: 4H5P_loop.csv
# no junction loops found: 5DHB_loop.csv
# no junction loops found: 1DQF_loop.csv
# no junction loops found: 5DHC_loop.csv
# no junction loops found: 6E0O_loop.csv
# no junction loops found: 438D_loop.csv
# no junction loops found: 1J1U_loop.csv
# no junction loops found: 3I62_loop.csv
# no junction loops found: 4RBY_loop.csv
# no junction loops found: 7D3J_loop.csv
# no junction loops found: 3S49_loop.csv
# no junction loops found: 6IA2_loop.csv
# no junction loops found: 397D_loop.csv
# no junction loops found: 2AB4_loop.csv
# no junction loops found: 7EAG_loop.csv
# no junction loops found: 6D2Z_loop.csv
# no junction loops found: 5Y85_loop.csv
# no junction loops found: 3K5Z_loop.csv
# no junction loops found: 1UTD_loop.csv
# no junction loops found: 2PN4_loop.csv
# no junction loops found: 5F8H_loop.csv
# no junction loops found: 5TDJ_loop.csv
# no junction loops found: 3LRR_loop.csv
# no junction loops found: 4RMO_loop.csv
# no junction loops found: 5A0T_loop.csv
# no junction loops found: 5GUH_loop.csv
# no junction loops found: 7A9X_loop.csv
# no junction loops found: 6JIM_loop.csv
# no junction loops found: 5C5W_loop.csv
# no junction loops found: 4IQX_loop.csv
# no junction loops found: 3RW6_loop.csv
# no junction loops found: 2Y9H_loop.csv
# no junction loops found: 5DDP_loop.csv
# no junction loops found: 6JJH_loop.csv
# no junction loops found: 5NXT_loop.csv
# no junction loops found: 6KWQ_loop.csv
# no junction loops found: 1LNT_loop.csv
# no junction loops found: 1EC6_loop.csv
# no junction loops found: 3SKI_loop.csv
# no junction loops found: 1H2C_loop.csv
# no junction loops found: 4Z0C_loop.csv
# no junction loops found: 5AXM_loop.csv
# no junction loops found: 6E8U_loop.csv
# no junction loops found: 5D0A_loop.csv
# no junction loops found: 1QC0_loop.csv
# no junction loops found: 7Z42_loop.csv
# no junction loops found: 5ZSL_loop.csv
# no junction loops found: 5I9H_loop.csv
# no junction loops found: 6GD2_loop.csv
# no junction loops found: 6GD3_loop.csv
# no junction loops found: 2A43_loop.csv
# no junction loops found: 5ELH_loop.csv
# no junction loops found: 5UDI_loop.csv
# no junction loops found: 435D_loop.csv
# no junction loops found: 3QGC_loop.csv
# no junction loops found: 3QGB_loop.csv
# no junction loops found: 1YVP_loop.csv
# no junction loops found: 7KUN_loop.csv
# no junction loops found: 4O41_loop.csv
# no junction loops found: 3JXQ_loop.csv
# no junction loops found: 2G4B_loop.csv
# no junction loops found: 4G9Z_loop.csv
# no junction loops found: 2ASB_loop.csv
# no junction loops found: 5KI6_loop.csv
# no junction loops found: 7L0Z_loop.csv
# no junction loops found: 1WPU_loop.csv
# no junction loops found: 2UWM_loop.csv
# no junction loops found: 1C9S_loop.csv
# no junction loops found: 3K5Q_loop.csv
# no junction loops found: 2AO5_loop.csv
# no junction loops found: 5K8H_loop.csv
# no junction loops found: 1DI2_loop.csv
# no junction loops found: 6GC5_loop.csv
# no junction loops found: 353D_loop.csv
# no junction loops found: 5F5H_loop.csv
# no junction loops found: 4KRE_loop.csv
# no junction loops found: 4YCO_loop.csv
# no junction loops found: 5HK0_loop.csv
# no junction loops found: 2XZL_loop.csv
# no junction loops found: 5GXI_loop.csv
# no junction loops found: 5GXH_loop.csv
# no junction loops found: 6VEM_loop.csv
# no junction loops found: 421D_loop.csv
# no junction loops found: 5WS2_loop.csv
# no junction loops found: 4K4S_loop.csv
# no junction loops found: 6U8D_loop.csv
# no junction loops found: 3BOY_loop.csv
# no junction loops found: 7K5L_loop.csv
# no junction loops found: 1QU2_loop.csv
# no junction loops found: 6A6J_loop.csv
# no junction loops found: 5EW4_loop.csv
# no junction loops found: 5JRC_loop.csv
# no junction loops found: 2G91_loop.csv
# no junction loops found: 3O7V_loop.csv
# no junction loops found: 3Q0Q_loop.csv
# no junction loops found: 5LR3_loop.csv
# no junction loops found: 1FIX_loop.csv
# no junction loops found: 1YZD_loop.csv
# no junction loops found: 2XS7_loop.csv
# no junction loops found: 7DOL_loop.csv
# no junction loops found: 4GV6_loop.csv
# no junction loops found: 1R9F_loop.csv
# no junction loops found: 1I9X_loop.csv
# no junction loops found: 5ZUU_loop.csv
# no junction loops found: 4X4T_loop.csv
# no junction loops found: 6NOH_loop.csv
# no junction loops found: 6L5N_loop.csv
# no junction loops found: 1L2X_loop.csv
# no junction loops found: 6WXY_loop.csv
# no junction loops found: 5HJZ_loop.csv
# no junction loops found: 464D_loop.csv
# no junction loops found: 7M50_loop.csv
# no junction loops found: 4J50_loop.csv
# no junction loops found: 5Z4D_loop.csv
# no junction loops found: 2XNR_loop.csv
# no junction loops found: 6FPQ_loop.csv
# no junction loops found: 2O5I_loop.csv
# no junction loops found: 3LA5_loop.csv
# no junction loops found: 1YYK_loop.csv
# no junction loops found: 5B2T_loop.csv
# no junction loops found: 7N0D_loop.csv
# no junction loops found: 2ZUE_loop.csv
# no junction loops found: 3IEV_loop.csv
# no junction loops found: 6AR5_loop.csv
# no junction loops found: 2BGG_loop.csv
# no junction loops found: 6UGG_loop.csv
# no junction loops found: 2Y8W_loop.csv
# no junction loops found: 6QIT_loop.csv
# no junction loops found: 5GJB_loop.csv
# no junction loops found: 6TQA_loop.csv
# no junction loops found: 1ZX7_loop.csv
# no junction loops found: 5HO4_loop.csv
# no junction loops found: 2I82_loop.csv
# no junction loops found: 7MKY_loop.csv
# no junction loops found: 4OLA_loop.csv
# no junction loops found: 5NS3_loop.csv
# no junction loops found: 4WAN_loop.csv
# no junction loops found: 5F8N_loop.csv
# no junction loops found: 7K16_loop.csv
# no junction loops found: 6YMC_loop.csv
# no junction loops found: 3M7N_loop.csv
# no junction loops found: 4CS1_loop.csv
# no junction loops found: 7KKV_loop.csv
# no junction loops found: 1KFO_loop.csv
# no junction loops found: 3RKF_loop.csv
# no junction loops found: 4LJ0_loop.csv
# no junction loops found: 1QBP_loop.csv
# no junction loops found: 7VNV_loop.csv
# no junction loops found: 3CZW_loop.csv
# no junction loops found: 4BW0_loop.csv
# no junction loops found: 2W89_loop.csv
# no junction loops found: 4LX6_loop.csv
# no junction loops found: 4HT9_loop.csv
# no junction loops found: 354D_loop.csv
# no junction loops found: 6E8S_loop.csv
# no junction loops found: 1D4R_loop.csv
# no junction loops found: 1J9H_loop.csv
# no junction loops found: 5H9F_loop.csv
# no junction loops found: 7Q4O_loop.csv
# no junction loops found: 5HKC_loop.csv
# no junction loops found: 1M8W_loop.csv
# no junction loops found: 2V7R_loop.csv
# no junction loops found: 1U0B_loop.csv
# no junction loops found: 1ICG_loop.csv
# no junction loops found: 4PKD_loop.csv
# no junction loops found: 413D_loop.csv
# no junction loops found: 280D_loop.csv
# no junction loops found: 6UV1_loop.csv
# no junction loops found: 6GX6_loop.csv
# no junction loops found: 6CK5_loop.csv
# no junction loops found: 3SQX_loop.csv
# no junction loops found: 5YTV_loop.csv
# no junction loops found: 4ZLD_loop.csv
# no junction loops found: 4GG4_loop.csv
# no junction loops found: 4C8Y_loop.csv
# no junction loops found: 6D30_loop.csv
# no junction loops found: 4RJ1_loop.csv
# no junction loops found: 5LYS_loop.csv
# no junction loops found: 4RKV_loop.csv
# no junction loops found: 418D_loop.csv
# no junction loops found: 4NGC_loop.csv
# no junction loops found: 3PF4_loop.csv
# no junction loops found: 3ADD_loop.csv
# no junction loops found: 4QVC_loop.csv
# no junction loops found: 3K62_loop.csv
# no junction loops found: 3GM7_loop.csv
# no junction loops found: 1UVJ_loop.csv
# no junction loops found: 3GLP_loop.csv
# no junction loops found: 4G0A_loop.csv
# no junction loops found: 7K98_loop.csv
# no junction loops found: 7M2V_loop.csv
# no junction loops found: 6GVY_loop.csv
# no junction loops found: 1FEU_loop.csv
# no junction loops found: 3MDG_loop.csv
# no junction loops found: 5ID6_loop.csv
# no junction loops found: 1YTU_loop.csv
# no junction loops found: 5XH7_loop.csv
# no junction loops found: 5KLA_loop.csv
# no junction loops found: 5H3U_loop.csv
# no junction loops found: 4U3L_loop.csv
# no junction loops found: 6ZM2_loop.csv
# no junction loops found: 6HC5_loop.csv
# no junction loops found: 6PPP_loop.csv
# no junction loops found: 4QOZ_loop.csv
# no junction loops found: 6PPQ_loop.csv
# no junction loops found: 5EV3_loop.csv
# no junction loops found: 6D12_loop.csv
# no junction loops found: 6QN3_loop.csv
# no junction loops found: 3SZX_loop.csv
# no junction loops found: 3R2C_loop.csv
# no junction loops found: 3P4D_loop.csv
# no junction loops found: 4NFQ_loop.csv
# no junction loops found: 6Q1H_loop.csv
# no junction loops found: 5WWW_loop.csv
# no junction loops found: 4PCJ_loop.csv
# no junction loops found: 1Y27_loop.csv
# no junction loops found: 1Y26_loop.csv
# no junction loops found: 3D2V_loop.csv
# no junction loops found: 6R7G_loop.csv
# no junction loops found: 6YRQ_loop.csv
# no junction loops found: 6N6F_loop.csv
# no junction loops found: 4TZ0_loop.csv
# no junction loops found: 2VOD_loop.csv
# no junction loops found: 6U6Y_loop.csv
# no junction loops found: 4ATO_loop.csv
# no junction loops found: 3BNR_loop.csv
# no junction loops found: 3RG5_loop.csv
# no junction loops found: 2F8K_loop.csv
# no junction loops found: 2ZKO_loop.csv
# no junction loops found: 5CCB_loop.csv
# no junction loops found: 4PR6_loop.csv
# no junction loops found: 6DCC_loop.csv
# no junction loops found: 4M4O_loop.csv
# no junction loops found: 5JS1_loop.csv
# no junction loops found: 4JF2_loop.csv
# no junction loops found: 5AY2_loop.csv
# no junction loops found: 4J7L_loop.csv
# no junction loops found: 7LO9_loop.csv
# no junction loops found: 2NZ4_loop.csv
# no junction loops found: 1Q96_loop.csv
# no junction loops found: 4XWF_loop.csv
# no junction loops found: 3H5X_loop.csv
# no junction loops found: 6RA4_loop.csv
# no junction loops found: 2J0S_loop.csv
# no junction loops found: 6LSF_loop.csv
# no junction loops found: 6LSG_loop.csv
# no junction loops found: 6JVX_loop.csv
# no junction loops found: 2ZY6_loop.csv
# no junction loops found: 5UDZ_loop.csv
# no junction loops found: 7NDJ_loop.csv
# no junction loops found: 5DNO_loop.csv
# no junction loops found: 2G8I_loop.csv
# no junction loops found: 1JID_loop.csv
# no junction loops found: 3Q0N_loop.csv
# no junction loops found: 7OAX_loop.csv
# no junction loops found: 3CGR_loop.csv
# no junction loops found: 2ATW_loop.csv
# no junction loops found: 3G9Y_loop.csv
# no junction loops found: 3CGS_loop.csv
# no junction loops found: 5NWQ_loop.csv
# no junction loops found: 420D_loop.csv
# no junction loops found: 7EU9_loop.csv
# no junction loops found: 2DLC_loop.csv
# no junction loops found: 6RT4_loop.csv
# no junction loops found: 6MFN_loop.csv
# no junction loops found: 2PJP_loop.csv
# no junction loops found: 6RT5_loop.csv
# no junction loops found: 7JRR_loop.csv
# no junction loops found: 2VOO_loop.csv
# no junction loops found: 2VON_loop.csv
# no junction loops found: 4E5C_loop.csv
# no junction loops found: 2DB3_loop.csv
# no junction loops found: 3R9W_loop.csv
# no junction loops found: 5TSN_loop.csv
# no junction loops found: 5JBG_loop.csv
# no junction loops found: 6XL9_loop.csv
# no junction loops found: 4YOE_loop.csv
# no junction loops found: 5AWH_loop.csv
# no junction loops found: 3QRP_loop.csv
# no junction loops found: 7EDT_loop.csv
# no junction loops found: 7P9I_loop.csv
# no junction loops found: 5F0Q_loop.csv
# no junction loops found: 315D_loop.csv
# no junction loops found: 409D_loop.csv
# no junction loops found: 3T3O_loop.csv
# no junction loops found: 5I4A_loop.csv
# no junction loops found: 6OON_loop.csv
# no junction loops found: 3P59_loop.csv
# no junction loops found: 5VAJ_loop.csv
# no junction loops found: 6DP8_loop.csv
# no junction loops found: 2JEA_loop.csv
# no junction loops found: 6KWR_loop.csv
# no junction loops found: 7EL1_loop.csv
# no junction loops found: 6S8B_loop.csv
# no junction loops found: 1ZCI_loop.csv
# no junction loops found: 4JGN_loop.csv
# no junction loops found: 4PQV_loop.csv
# no junction loops found: 1MHK_loop.csv
# no junction loops found: 7LNE_loop.csv
# no junction loops found: 1GTN_loop.csv
# no junction loops found: 5WLH_loop.csv
# no junction loops found: 5FQ5_loop.csv
# no junction loops found: 6FQL_loop.csv
# no junction loops found: 3ND3_loop.csv
# no junction loops found: 1SDS_loop.csv
# no junction loops found: 6SCE_loop.csv
# no junction loops found: 3BSX_loop.csv
# no junction loops found: 2Q1O_loop.csv
# no junction loops found: 5ZSN_loop.csv
# no junction loops found: 6KQF_loop.csv
# no junction loops found: 4NLF_loop.csv
# no junction loops found: 3NJ7_loop.csv
# no junction loops found: 3HAX_loop.csv
# no junction loops found: 1R3E_loop.csv
# no junction loops found: 3B0U_loop.csv
# no junction loops found: 6UGI_loop.csv
# no junction loops found: 2Y8Y_loop.csv
# no junction loops found: 6BSG_loop.csv
# no junction loops found: 5ELK_loop.csv
# no junction loops found: 6OZO_loop.csv
# no junction loops found: 1KNZ_loop.csv
# no junction loops found: 4KRF_loop.csv
# no junction loops found: 4XWW_loop.csv
# no junction loops found: 6CB3_loop.csv
# no junction loops found: 3AVX_loop.csv
# no junction loops found: 7V4G_loop.csv
# no junction loops found: 5YTS_loop.csv
# no junction loops found: 5Z4J_loop.csv
# no junction loops found: 3E5C_loop.csv
# no junction loops found: 4KYY_loop.csv
# no junction loops found: 5AOR_loop.csv
# no junction loops found: 2XSL_loop.csv
# no junction loops found: 6UV4_loop.csv
# no junction loops found: 6DTD_loop.csv
# no junction loops found: 4RBQ_loop.csv
# no junction loops found: 5ZSE_loop.csv
# no junction loops found: 4JNG_loop.csv
# no junction loops found: 2XS2_loop.csv
# no junction loops found: 404D_loop.csv
# no junction loops found: 7EIU_loop.csv
# no junction loops found: 7BAH_loop.csv
# no junction loops found: 3NNA_loop.csv
# no junction loops found: 4JZU_loop.csv
# no junction loops found: 1QTQ_loop.csv
# no junction loops found: 6D1V_loop.csv
# no junction loops found: 1M8X_loop.csv
# no junction loops found: 4M59_loop.csv
# no junction loops found: 5WWF_loop.csv
# no junction loops found: 5WWG_loop.csv
# no junction loops found: 2Q66_loop.csv
# no junction loops found: 6SZV_loop.csv
# no junction loops found: 4Z31_loop.csv
# no junction loops found: 6EEN_loop.csv
# no junction loops found: 283D_loop.csv
# no junction loops found: 6YML_loop.csv
# no junction loops found: 5UD5_loop.csv
# no junction loops found: 3FS0_loop.csv
# no junction loops found: 4WTJ_loop.csv
# no junction loops found: 3KMQ_loop.csv
# no junction loops found: 4WTK_loop.csv
# no junction loops found: 5B2P_loop.csv
# no junction loops found: 2XLK_loop.csv
# no junction loops found: 2A8V_loop.csv
# no junction loops found: 2OEU_loop.csv
# no junction loops found: 4RBZ_loop.csv
# no junction loops found: 4JRD_loop.csv
# no junction loops found: 6FQ3_loop.csv
# no junction loops found: 3TS2_loop.csv
# no junction loops found: 5AOX_loop.csv
# no junction loops found: 5MFX_loop.csv
# no junction loops found: 4K4Z_loop.csv
# no junction loops found: 1PJG_loop.csv
# no junction loops found: 5YTX_loop.csv
# no junction loops found: 7KQN_loop.csv
# no junction loops found: 5VOE_loop.csv
# no junction loops found: 5U0Q_loop.csv
# no junction loops found: 5X2G_loop.csv
# no junction loops found: 5Z4A_loop.csv
# no junction loops found: 3OVB_loop.csv
# no junction loops found: 1T0E_loop.csv
# no junction loops found: 3OIN_loop.csv
# no junction loops found: 6XLW_loop.csv
# no junction loops found: 7OS0_loop.csv
# no junction loops found: 2NUG_loop.csv
# no junction loops found: 3LOA_loop.csv
# no junction loops found: 6X5M_loop.csv
# no junction loops found: 3VYX_loop.csv
# no junction loops found: 4O8J_loop.csv
# no junction loops found: 1TFW_loop.csv
# no junction loops found: 3RER_loop.csv
# no junction loops found: 4QPX_loop.csv
# no junction loops found: 4QU6_loop.csv
# no junction loops found: 5AH5_loop.csv
# no junction loops found: 4QU7_loop.csv
# no junction loops found: 1MDG_loop.csv
# no junction loops found: 3R1C_loop.csv
# no junction loops found: 2X1F_loop.csv
# no junction loops found: 332D_loop.csv
# no junction loops found: 5DET_loop.csv
# no junction loops found: 4KTG_loop.csv
# no junction loops found: 3V74_loop.csv
# no junction loops found: 3MDI_loop.csv
# no junction loops found: 5D5L_loop.csv
# no junction loops found: 2GRB_loop.csv
# no junction loops found: 7OUO_loop.csv
# no junction loops found: 3VJR_loop.csv
# no junction loops found: 2G3S_loop.csv
# no junction loops found: 6M6R_loop.csv
# no junction loops found: 1EFO_loop.csv
# no junction loops found: 6M6S_loop.csv
# no junction loops found: 3T5N_loop.csv
# no junction loops found: 4NKU_loop.csv
# no junction loops found: 7DIC_loop.csv
# no junction loops found: 255D_loop.csv
# no junction loops found: 6DCL_loop.csv
# no junction loops found: 4MDX_loop.csv
# no junction loops found: 4KNQ_loop.csv
# no junction loops found: 3TD0_loop.csv
# no junction loops found: 6TFG_loop.csv
# no junction loops found: 4F02_loop.csv
# no junction loops found: 5WWX_loop.csv
# no junction loops found: 3ZGZ_loop.csv
# no junction loops found: 3IBK_loop.csv
# no junction loops found: 7CGK_loop.csv
# no junction loops found: 2JLV_loop.csv
# no junction loops found: 2Z75_loop.csv
# no junction loops found: 6N6H_loop.csv
# no junction loops found: 6N6I_loop.csv
# no junction loops found: 6YL5_loop.csv
# no junction loops found: 4LVW_loop.csv
# no junction loops found: 4QCL_loop.csv
# no junction loops found: 4E58_loop.csv
# no junction loops found: 3V6Y_loop.csv
# no junction loops found: 4E59_loop.csv
# no junction loops found: 6L1W_loop.csv
# no junction loops found: 7A9N_loop.csv
# no junction loops found: 3B31_loop.csv
# no junction loops found: 5ELT_loop.csv
# no junction loops found: 2HVY_loop.csv
# no junction loops found: 6UEJ_loop.csv
# no junction loops found: 5NFV_loop.csv
# no junction loops found: 1QLN_loop.csv
# no junction loops found: 1F7U_loop.csv
# no junction loops found: 4E6B_loop.csv
# no junction loops found: 6OZP_loop.csv
# no junction loops found: 217D_loop.csv
# no junction loops found: 4QIK_loop.csv
# no junction loops found: 4HOR_loop.csv
# no junction loops found: 6DMC_loop.csv
# no junction loops found: 4HOS_loop.csv
# no junction loops found: 398D_loop.csv
# no junction loops found: 2ANN_loop.csv
# no junction loops found: 7EQJ_loop.csv
# no junction loops found: 5SWD_loop.csv
# no junction loops found: 1OOA_loop.csv
# no junction loops found: 3FHT_loop.csv
# no junction loops found: 7S3A_loop.csv
# no junction loops found: 4PRF_loop.csv
# no junction loops found: 6M7K_loop.csv
# no junction loops found: 5H1L_loop.csv
# no junction loops found: 6H0R_loop.csv
# no junction loops found: 5ZQ8_loop.csv
# no junction loops found: 6LSH_loop.csv
# no junction loops found: 4LGT_loop.csv
# no junction loops found: 2VPL_loop.csv
# no junction loops found: 4YYE_loop.csv
# no junction loops found: 6N6C_loop.csv
# no junction loops found: 5EMF_loop.csv
# no junction loops found: 1Z7F_loop.csv
# no junction loops found: 3D2S_loop.csv
# no junction loops found: 4PCO_loop.csv
# no junction loops found: 2PO1_loop.csv
# no junction loops found: 4GHL_loop.csv
# no junction loops found: 2FQN_loop.csv
# no junction loops found: 3SJ2_loop.csv
# no junction loops found: 402D_loop.csv
# no junction loops found: 6PUN_loop.csv
# no junction loops found: 5BZV_loop.csv
# no junction loops found: 4RWN_loop.csv
# no junction loops found: 4AL5_loop.csv
# no junction loops found: 5K77_loop.csv
# no junction loops found: 5THE_loop.csv
# no junction loops found: 1MJI_loop.csv
# no junction loops found: 1L3Z_loop.csv
# no junction loops found: 6D8A_loop.csv
# no junction loops found: 2OE5_loop.csv
# no junction loops found: 6IV9_loop.csv
# no junction loops found: 4QM6_loop.csv
# no junction loops found: 6SAG_loop.csv
# no junction loops found: 4KXT_loop.csv
# no junction loops found: 4FEN_loop.csv
# no junction loops found: 6FQR_loop.csv
# no junction loops found: 1ZBI_loop.csv
# no junction loops found: 4OAV_loop.csv
# no junction loops found: 1N78_loop.csv
# no junction loops found: 4ZLR_loop.csv
# no junction loops found: 7D8O_loop.csv
# no junction loops found: 1F27_loop.csv
# no junction loops found: 6F4G_loop.csv
# no junction loops found: 6I0V_loop.csv
# no junction loops found: 3OL9_loop.csv
# no junction loops found: 6LSE_loop.csv
# no junction loops found: 3WBM_loop.csv
# no junction loops found: 1FUF_loop.csv
# no junction loops found: 246D_loop.csv
# no junction loops found: 1QCU_loop.csv
# no junction loops found: 4J39_loop.csv
# no junction loops found: 3NKB_loop.csv
# no junction loops found: 1FXL_loop.csv
# no junction loops found: 4K31_loop.csv
# no junction loops found: 3ADL_loop.csv
# no junction loops found: 5JAJ_loop.csv
# no junction loops found: 472D_loop.csv
# no junction loops found: 4JIY_loop.csv
# no junction loops found: 3R1D_loop.csv
# no junction loops found: 2B3J_loop.csv
# no junction loops found: 3R1E_loop.csv
# no junction loops found: 2QUW_loop.csv
# no junction loops found: 3AHU_loop.csv
# no junction loops found: 5U3G_loop.csv
# no junction loops found: 4XW0_loop.csv
# no junction loops found: 7KL3_loop.csv
# no junction loops found: 4XW1_loop.csv
# no junction loops found: 3Q0L_loop.csv
# no junction loops found: 6RT7_loop.csv
# no junction loops found: 6RT6_loop.csv
# no junction loops found: 3GIB_loop.csv
# no junction loops found: 6XH2_loop.csv
# no junction loops found: 6HAU_loop.csv
# no junction loops found: 4R3I_loop.csv
# no junction loops found: 3GVN_loop.csv
# no junction loops found: 1CSL_loop.csv
# no junction loops found: 5LQT_loop.csv
# no junction loops found: 2OE8_loop.csv
# no junction loops found: 3CGP_loop.csv
# no junction loops found: 1G2J_loop.csv
# no junction loops found: 4KZD_loop.csv
# no junction loops found: 5XUZ_loop.csv
# no junction loops found: 4N0T_loop.csv
# no junction loops found: 4JAH_loop.csv
# no junction loops found: 1P79_loop.csv
# no junction loops found: 5L00_loop.csv
# no junction loops found: 3CJZ_loop.csv
# no junction loops found: 5MWI_loop.csv
# no junction loops found: 5W1H_loop.csv
# no junction loops found: 1M5K_loop.csv
# no junction loops found: 4GHA_loop.csv
# no junction loops found: 7MJV_loop.csv
# no junction loops found: 7OM7_loop.csv
# no junction loops found: 7MJW_loop.csv
# no junction loops found: 6XRQ_loop.csv
# no junction loops found: 2V6W_loop.csv
# no junction loops found: 7CGL_loop.csv
# no junction loops found: 7Z26_loop.csv
# no junction loops found: 3K61_loop.csv
# no junction loops found: 377D_loop.csv
# no junction loops found: 4HOT_loop.csv
# no junction loops found: 1UVI_loop.csv
# no junction loops found: 6DOY_loop.csv
# no junction loops found: 2VNU_loop.csv
# no junction loops found: 2HW8_loop.csv
# no junction loops found: 5ELR_loop.csv
# no junction loops found: 5VJ9_loop.csv
# no junction loops found: 5ZC9_loop.csv
# no junction loops found: 6XJQ_loop.csv
# no junction loops found: 7L6T_loop.csv
# no junction loops found: 5H1K_loop.csv
# no junction loops found: 6RTI_loop.csv
# no junction loops found: 2VUQ_loop.csv
# no junction loops found: 5EV1_loop.csv
# no junction loops found: 2QKB_loop.csv
# no junction loops found: 2GXB_loop.csv
# no junction loops found: 5V1K_loop.csv
# no junction loops found: 6G3B_loop.csv
# no junction loops found: 7CGF_loop.csv
# no junction loops found: 5M3H_loop.csv
# no junction loops found: 3OK4_loop.csv
# no junction loops found: 6N6E_loop.csv
# no junction loops found: 6N6D_loop.csv
# no junction loops found: 3AM1_loop.csv
# no junction loops found: 4JAB_loop.csv
# no junction loops found: 4ED5_loop.csv
# no junction loops found: 2BH2_loop.csv
# no junction loops found: 5Z1I_loop.csv
# no junction loops found: 1MSW_loop.csv
# no junction loops found: 1JBR_loop.csv
# no junction loops found: 4H8K_loop.csv
# no junction loops found: 7BV2_loop.csv
# no junction loops found: 3L25_loop.csv
# no junction loops found: 7D81_loop.csv
# no junction loops found: 4JXZ_loop.csv
# no junction loops found: 4K27_loop.csv
# no junction loops found: 5KVJ_loop.csv
# no junction loops found: 4OOG_loop.csv
# no junction loops found: 3AGV_loop.csv
# no junction loops found: 4U6K_loop.csv
# no junction loops found: 4P97_loop.csv
# no junction loops found: 3DIL_loop.csv
# no junction loops found: 6Q8V_loop.csv
# no junction loops found: 4ILL_loop.csv
# no junction loops found: 4TYW_loop.csv
# no junction loops found: 3KOA_loop.csv
# no junction loops found: 2R1S_loop.csv
# no junction loops found: 3MEI_loop.csv
# no junction loops found: 4PY5_loop.csv
# no junction loops found: 3BNN_loop.csv
# no junction loops found: 6E1S_loop.csv
# no junction loops found: 5EBI_loop.csv
# no junction loops found: 5N94_loop.csv
# no junction loops found: 3ND4_loop.csv
# no junction loops found: 5O1Y_loop.csv
# no junction loops found: 6WYB_loop.csv
# no junction loops found: 1DFU_loop.csv
# no junction loops found: 2C4Q_loop.csv
# no junction loops found: 3QSU_loop.csv
# no junction loops found: 6SX2_loop.csv
# no junction loops found: 5ZW4_loop.csv
# no junction loops found: 5FJC_loop.csv
# no junction loops found: 5L2L_loop.csv
# no junction loops found: 5W0O_loop.csv
# no junction loops found: 3DD2_loop.csv
# no junction loops found: 1YZ9_loop.csv
# no junction loops found: 6FPX_loop.csv
# no junction loops found: 1DQH_loop.csv
# no junction loops found: 3SSF_loop.csv
# no junction loops found: 6UV2_loop.csv
# no junction loops found: 6UV3_loop.csv
# no junction loops found: 4RC0_loop.csv
# no junction loops found: 5D8T_loop.csv
# no junction loops found: 6H9H_loop.csv
# no junction loops found: 4C8Z_loop.csv
# no junction loops found: 5YTT_loop.csv
# no junction loops found: 7PO6_loop.csv
# no junction loops found: 2G92_loop.csv
# no junction loops found: 3Q0S_loop.csv
# no junction loops found: 5WZJ_loop.csv
# no junction loops found: 3Q0R_loop.csv
# no junction loops found: 4V4F_loop.csv
# no junction loops found: 3BSU_loop.csv
# no junction loops found: 4Z4D_loop.csv
# no junction loops found: 4PEH_loop.csv
# no junction loops found: 2XS5_loop.csv
# no junction loops found: 5ZSC_loop.csv
# no junction loops found: 5I9F_loop.csv
# no junction loops found: 5I9G_loop.csv
# no junction loops found: 4TU0_loop.csv
# no junction loops found: 3LQX_loop.csv
# no junction loops found: 6SQN_loop.csv
# no junction loops found: 4E48_loop.csv
# no junction loops found: 4WTM_loop.csv
# no junction loops found: 4WTL_loop.csv
# no junction loops found: 6V9B_loop.csv
# no junction loops found: 485D_loop.csv
# no junction loops found: 5Z98_loop.csv
# no junction loops found: 6DO8_loop.csv
# no junction loops found: 7EOG_loop.csv
# no junction loops found: 4KQ0_loop.csv
# no junction loops found: 3HGA_loop.csv
# no junction loops found: 6X1B_loop.csv
# no junction loops found: 3OG8_loop.csv
# no junction loops found: 1A9N_loop.csv
# no junction loops found: 2DRA_loop.csv
# no junction loops found: 3K1V_loop.csv
# no junction loops found: 3P22_loop.csv
# no junction loops found: 4BWM_loop.csv
# no junction loops found: 3U4M_loop.csv
# no junction loops found: 2AWE_loop.csv
# no junction loops found: 4MCF_loop.csv
# no junction loops found: 6TQB_loop.csv
# no junction loops found: 4L8H_loop.csv
# no junction loops found: 7RZZ_loop.csv
# no junction loops found: 3PEY_loop.csv
# no junction loops found: 5BZ1_loop.csv
# no junction loops found: 3K49_loop.csv
# no junction loops found: 7BPG_loop.csv
# no junction loops found: 7BPF_loop.csv
# no junction loops found: 6IS0_loop.csv

# %%
import os, sys, shutil
import pathlib
import glob as glob
import numpy as np
import re
import warnings
from pdbfixer import PDBFixer
from openmm.app import PDBxFile, PDBFile

# %%
#warnings.filterwarnings("ignore")

# %%
def replace_string(l, chain, new_chain, rid, new_rid):
    if len(rid) == 1:
        nl = l.replace("{}   {}".format(chain, rid), "{}   {}".format(new_chain, new_rid))
    elif len(rid) == 2:
        nl = l.replace("{}  {}".format(chain, rid), "{}  {}".format(new_chain, new_rid))
    elif len(rid) == 3:
        nl = l.replace("{} {}".format(chain, rid), "{} {}".format(new_chain, new_rid))
    elif len(rid) == 4:
        nl = l.replace("{}{}".format(chain, rid), "{}{}".format(new_chain, new_rid))
    return nl

# %%
def renumber_resid(f):
    arr = []
    count = 0
    new_rid = 0
    with open(f, "r") as wf:
        for l in wf.readlines():
            if l.startswith('ATOM'):
                _l = l.strip('\n').split()
                aid = str(_l[1])
                aname = str(_l[2])
                
                # handle four digit resid (e.g. C1983)
                x = str(_l[4])
                if len(x) == 5:
                    chain = str(x[:1])
                    rid = str(x[1:])
                else:
                    chain = str(_l[4])
                    rid = str(_l[5])

                # convert numeric chain to alphabet
                if chain.isnumeric():
                    new_chain = "X"
                else:
                    new_chain = chain
                    
                # check resid update
                if aname == 'P':
                    new_rid = str(int(rid) + count)
                    nl = replace_string(l, chain, new_chain, rid, new_rid)
                    arr.append(nl)
                    count += 1
                else:
                    nl = replace_string(l, chain, new_chain, rid, new_rid)
                    arr.append(nl)
            else:
                arr.append(l)

    # export pdb
    shutil.move(f, f + ".duplicateAtoms")
    with open(f, "w") as wf:
        for a in arr:
            wf.write(a)

# %%
def check_pdb(f):    
    n_warnings = 0
    basename = os.path.basename(f)
    #print(">{}".format(basename))
    
    
    with warnings.catch_warnings(record=True) as w:
        warnings.simplefilter("default")
        fixer = PDBFixer(filename=f)
    
    
    # check missing atoms
    fixer.findMissingResidues()
    fixer.findMissingAtoms()
    if fixer.missingAtoms:
        n_warnings += 1

        print("{}: Missing atoms -> Will be removed in the next step".format(basename))
        shutil.move(f, f + ".missingAtoms")

        
    # check duplicate atoms (same residue ID)
    x = [ x for x in w if "duplicate atom" in str(x) ]
    if len(x) != 0:
        n_warnings += 1
        
        print("{}: Duplicate atoms -> Renumber residue ID".format(basename))
        renumber_resid(f)
        
    if n_warnings == 0:
        #print("pass")
        pass

# %%
if __name__ == "__main__":
    base_path = os.path.dirname(os.path.abspath("__file__")).strip('notebooks')
    
    #files = glob.glob("/Users/takabak/sftp/test/*.pdb")
    
    files_for_bpcatalog = glob.glob(os.path.join(base_path) + "pdb/bpcatalog/*.pdb")
    files_for_triplebase = glob.glob(os.path.join(base_path) + "pdb/triplebase/*/*.pdb")
    files_for_hairpins = glob.glob(os.path.join(base_path) + "pdb/motif/HairpinLoopMotifAtlasRelease3.57/*/*.pdb")
    files_for_internals = glob.glob(os.path.join(base_path) + "pdb/motif/InternalLoopMotifAtlasRelease3.57/*/*.pdb")
    files_for_junctions = glob.glob(os.path.join(base_path) + "pdb/motif/nrlist_3.233_2.5A/JunctionLoop/*/*.pdb")
    
    files = files_for_bpcatalog + files_for_triplebase + files_for_hairpins + files_for_internals + files_for_junctions
    #files = files_for_triplebase
    
    for f in files:
        check_pdb(f)
# Out:
# BP_cWS_AC.pdb: Missing atoms -> Will be removed in the next step
# BP_cWH_GG.pdb: Duplicate atoms -> Renumber residue ID
# BP_tWH_CG.pdb: Missing atoms -> Will be removed in the next step
# BP_tWS_AG.pdb: Missing atoms -> Will be removed in the next step
# BP_cWH_UU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHS_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSW_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSH_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSS_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHS_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHH_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSW_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHW_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSH_AAC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSW_UCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tHW_tHS_GCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cHW_cHW_CCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSW_cSW_CCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSH_tSH_CCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tHW_tHW_CCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSW_CCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSH_cSH_CCC.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tHW_tHW_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHS_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSH_cSH_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSW_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSS_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSH_tSH_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSW_cSW_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSH_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHH_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHS_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSW_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHW_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tsS_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSH_AAA.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tHW_tHW_UUU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSH_cSH_UUU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSW_UUU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cHW_cHW_UUU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSW_cSW_UUU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cHW_cHW_GGG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSH_tSH_GGG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSW_cSW_GGG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tHW_tHW_GGG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_cSH_cSH_GGG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHH_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHS_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSS_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHW_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSW_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHH_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHS_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tsS_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSH_AAG.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHS_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSW_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHW_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSS_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tSH_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHH_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cHS_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSW_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_tHW_AAU.pdb: Duplicate atoms -> Renumber residue ID
# Triple_tSW_cSH_AAU.pdb: Duplicate atoms -> Renumber residue ID
# HL_01181.4_G_5.pdb: Missing atoms -> Will be removed in the next step
# HL_01181.4_C_7.pdb: Missing atoms -> Will be removed in the next step
# HL_49873.1_UA_8.pdb: Duplicate atoms -> Renumber residue ID
# HL_48810.1_UU_7.pdb: Duplicate atoms -> Renumber residue ID
# HL_51090.1_CA_8.pdb: Duplicate atoms -> Renumber residue ID
# HL_44730.2_CU_1.pdb: Duplicate atoms -> Renumber residue ID
# HL_01181.4_CG_4.pdb: Missing atoms -> Will be removed in the next step
# HL_44730.2_UU_2.pdb: Duplicate atoms -> Renumber residue ID
# HL_01181.4_UC_6.pdb: Missing atoms -> Will be removed in the next step
# HL_44730.2_GG_4.pdb: Duplicate atoms -> Renumber residue ID
# HL_01181.4_GU_5.pdb: Missing atoms -> Will be removed in the next step
# HL_44730.2_CC_0.pdb: Duplicate atoms -> Renumber residue ID
# HL_35188.1_CU_4.pdb: Duplicate atoms -> Renumber residue ID
# HL_70505.1_GC_5.pdb: Duplicate atoms -> Renumber residue ID
# HL_44730.2_UG_3.pdb: Duplicate atoms -> Renumber residue ID
# HL_19239.1_UA_8.pdb: Duplicate atoms -> Renumber residue ID
# HL_44730.2_UGG_3.pdb: Duplicate atoms -> Renumber residue ID
# HL_49873.1_UAG_8.pdb: Duplicate atoms -> Renumber residue ID
# HL_01181.4_CGU_4.pdb: Missing atoms -> Will be removed in the next step
# HL_01181.4_GUC_5.pdb: Missing atoms -> Will be removed in the next step
# HL_70505.1_AGC_4.pdb: Duplicate atoms -> Renumber residue ID
# HL_19239.1_UAG_8.pdb: Duplicate atoms -> Renumber residue ID
# HL_51090.1_CAG_8.pdb: Duplicate atoms -> Renumber residue ID
# HL_49873.1_GUA_7.pdb: Duplicate atoms -> Renumber residue ID
# HL_44730.2_UUG_2.pdb: Duplicate atoms -> Renumber residue ID
# HL_35188.1_CCU_3.pdb: Duplicate atoms -> Renumber residue ID
# HL_19239.1_GUA_7.pdb: Duplicate atoms -> Renumber residue ID
# HL_44730.2_CUU_1.pdb: Duplicate atoms -> Renumber residue ID
# HL_48810.1_GUU_6.pdb: Duplicate atoms -> Renumber residue ID
# HL_44730.2_CCU_0.pdb: Duplicate atoms -> Renumber residue ID
# HL_48810.1_UUA_7.pdb: Duplicate atoms -> Renumber residue ID
# HL_01181.4_CCG_3.pdb: Missing atoms -> Will be removed in the next step
# HL_35188.1_CUG_4.pdb: Duplicate atoms -> Renumber residue ID
# HL_70505.1_GCC_5.pdb: Duplicate atoms -> Renumber residue ID
# HL_51090.1_UCA_7.pdb: Duplicate atoms -> Renumber residue ID
# IL_64414.1_G_10.pdb: Missing atoms -> Will be removed in the next step
# IL_89836.1_AA_2.pdb: Duplicate atoms -> Renumber residue ID
# IL_64414.1_AG_9.pdb: Missing atoms -> Will be removed in the next step
# IL_77034.1_UA_3.pdb: Duplicate atoms -> Renumber residue ID
# IL_46464.1_AA_6.pdb: Duplicate atoms -> Renumber residue ID
# IL_46464.1_CA_5.pdb: Duplicate atoms -> Renumber residue ID
# IL_64414.1_GC_10.pdb: Missing atoms -> Will be removed in the next step
# IL_57188.3_UA_9.pdb: Duplicate atoms -> Renumber residue ID
# IL_57188.3_UUA_8.pdb: Duplicate atoms -> Renumber residue ID
# IL_57188.3_UAA_9.pdb: Duplicate atoms -> Renumber residue ID
# IL_46464.1_CAA_5.pdb: Duplicate atoms -> Renumber residue ID
# IL_77034.1_UAA_3.pdb: Duplicate atoms -> Renumber residue ID
# IL_77034.1_AUA_2.pdb: Duplicate atoms -> Renumber residue ID
# IL_46464.1_AAG_6.pdb: Duplicate atoms -> Renumber residue ID
# IL_46464.1_ACA_4.pdb: Duplicate atoms -> Renumber residue ID
# IL_89836.1_AAG_2.pdb: Duplicate atoms -> Renumber residue ID
# IL_64414.1_CAG_8.pdb: Missing atoms -> Will be removed in the next step
# IL_64414.1_AGC_9.pdb: Missing atoms -> Will be removed in the next step
# IL_64414.1_GCG_10.pdb: Missing atoms -> Will be removed in the next step
# IL_89836.1_GAA_1.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GU_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GU_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GU_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_UC_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_UC_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_UC_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_UC_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_UG_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GU_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GU_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GU_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_UG_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_AA_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_AA_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GU_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_UG_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_AC_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_AC_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GU_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_CG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_CG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GG_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GG_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GG_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GG_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_CG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_CG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_UG_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_AC_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_AC_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_AA_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_AA_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GUC_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_UGC_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GGU_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_AAC_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_ACG_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_AAA_1.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GUC_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_CGG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_CGU_9.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_UGC_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_UGC_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_CGG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GGG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_UCG_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_CGU_9.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GUG_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_AAC_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_ACG_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GGU_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GGG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_UCG_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_AAA_1.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GUC_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GUG_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GGG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_CGG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_ACG_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_AAC_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_UCG_8.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_AAA_1.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_CGG_4.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_ACG_3.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_AAC_2.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_AAA_1.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GUG_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_GGU_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_UGC_11.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_CGU_9.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_003_GUC_7.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GUG_10.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_GGG_5.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_030_GGU_6.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQB_003_CGU_9.pdb: Duplicate atoms -> Renumber residue ID
# J3_7RQ8_031_UCG_8.pdb: Duplicate atoms -> Renumber residue ID
